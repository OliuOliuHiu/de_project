# %%
import pandas as pd
import os
import sys
sys.path.append(os.path.abspath("D:\kidlor\data_engineer\project\de_project").replace("\\", "/"))
from src.extract import fetch_users, get_data_csv
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\k'
# <>:4: SyntaxWarning: invalid escape sequence '\k'
# C:\Users\hieuh\AppData\Local\Temp\ipykernel_4660\4059003303.py:4: SyntaxWarning: invalid escape sequence '\k'
#   sys.path.append(os.path.abspath("D:\kidlor\data_engineer\project\de_project").replace("\\", "/"))

# %%
df_api = fetch_users()
df_csv = pd.read_csv('../../data/orders.csv')
# Out:
# Status code: 200

# %%
df_api
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                                              address                  phone  \
# ...

# %%
df_csv
# Out:
#    order_id  user_id       product  quantity  price  order_date
# 0         1        1        Laptop         1   1200  2026-04-01
# 1         2        2         Mouse         2     25  2026-04-01
# 2         3        1      Keyboard         1     80  2026-04-02
# 3         4        3       Monitor         2    300  2026-04-02
# 4         5        4     USB Cable         5     10  2026-04-03
# 5         6       99     Headphone         1    150  2026-04-03
# 6         7        2  Laptop Stand         1     45  2026-04-04
# 7         8        3     Mouse Pad         3     12  2026-04-04

# %%
df_api.columns.tolist()
# Out:
# ['id', 'name', 'username', 'email', 'address', 'phone', 'website', 'company']

# %%
df_api = df_api.rename(columns = {"id": "user_id"})

# %%
df_api['user_id'] = 'uc' + df_api['user_id'].astype(str)

# %%
df_api['city'] = df_api.apply(lambda row: row['address']['city'], axis=1)
df_api['company_name'] = df_api.apply(lambda row: row['company']['name'], axis=1)

# %%
df_api_main = df_api[['user_id', 'name', 'email','phone', 'city', 'company_name']]

# %%
df_csv['user_id'] = 'uc' + df_csv['user_id'].astype(str)

# %%
df_api_main
# Out:
#   user_id                      name                      email  \
# 0     uc1             Leanne Graham          Sincere@april.biz
# 1     uc2              Ervin Howell          Shanna@melissa.tv
# 2     uc3          Clementine Bauch         Nathan@yesenia.net
# 3     uc4          Patricia Lebsack  Julianne.OConner@kory.org
# 4     uc5          Chelsey Dietrich   Lucio_Hettinger@annie.ca
# 5     uc6      Mrs. Dennis Schulist    Karley_Dach@jasper.info
# 6     uc7           Kurtis Weissnat     Telly.Hoeger@billy.biz
# 7     uc8  Nicholas Runolfsdottir V       Sherwood@rosamond.me
# 8     uc9           Glenna Reichert    Chaim_McDermott@dana.io
# 9    uc10        Clementina DuBuque     Rey.Padberg@karina.biz
#
#                    phone            city        company_name
# 0  1-770-736-8031 x56442     Gwenborough     Romaguera-Crona
# 1    010-692-6593 x09125     Wisokyburgh        Deckow-Crist
# 2         1-463-123-4447   McKenziehaven  Romaguera-Jacobson
# ...
